# %%
import tkinter as tk
import plotly
import plotly.graph_objects as go
import pandas as pd
from tkinter import *
from PIL import Image, ImageTk
import os
from plotly.subplots import make_subplots
  


def people_count():  
    excel_file = 'vaccinated_count.xls'
    df = pd.read_excel(excel_file)
    print(df)
    data1 = [go.Scatter( x=df['Time'],y=df['People_Vaccinated'],marker = {'color' : 'orange'})]
    fig1 = go.Figure(data1,layout=go.Layout(title=go.layout.Title(text="Count of Vaccinated People")))
    plotly.offline.plot(fig1, filename="vaccinated_people_time.html")


    data2 = go.Pie( labels=df['Time_slot'],values=df['Count'])
    
    fig2 = go.Figure(data2,layout=go.Layout(title=go.layout.Title(text="Count of Vaccinated People")))  

    #colors = ['mediumturquoise',  'darkorange', 'gold']
    colors = ['#bc5090',  '#58508d', '#ff6361']

    fig2.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=40,
                  marker=dict(colors=colors, line=dict(color='#000000', width=2)))

    plotly.offline.plot(fig2, filename="vaccinated_people.html")



def room_temp():  
    excel_file = 'temp_data.xls'
    df = pd.read_excel(excel_file)
    print(df)
    data1 = [go.Scatter( x=df['Time'],y=df['Temperature'],marker = {'color' : 'red'})]
    fig1 = go.Figure(data1,layout=go.Layout(title=go.layout.Title(text="Room1 Temperature")))
    plotly.offline.plot(fig1, filename="room_temperature.html")


def vaccin_stock():  
    fig = make_subplots(specs=[[{"secondary_y": True}]])

    excel_file = 'stock_count.xls'
    df = pd.read_excel(excel_file)
    print(df)

    fig.add_trace(
    go.Scatter(x=df['Time'],y=df['Pfizer'], name = "Pfizer"),
    secondary_y=False,
    )

    fig.add_trace(
    go.Scatter(x=df['Time'],y=df['Moderna'], name="Moderna")
    )

    fig.update_layout(
    title_text="Vaccine Stack Used "
    )
    fig.update_xaxes(title_text="<b>Time</b>")
    fig.update_yaxes(title_text="<b>Temperature</b>", secondary_y=False)
    #fig.show()
    plotly.offline.plot(fig, filename="vaccine_stocks.html")

def alarm():  
    print(1+2)
    aalarm()

def room1():
   a = "1"
   selection = str(var1.get())
   print(selection)
   slider(a,selection)
   
def room2():
   a = "1"
   selection = str(var2.get())
   print(selection)
   slider(a,selection)

def voice_msg():  
    #print("bandenee")
    os.system("user_msg.mp3")

def send_msg ():  
    x1 = entry1.get()
    print(x1)
    message_send(x1)
    
# --- main ---

# init    
root = tk.Tk()
root.configure(bg='black')

var1 = DoubleVar()
var2 = DoubleVar()



# load image


image4 = Image.open("db11.png")
image4 = image4.resize((180,170), Image.ANTIALIAS)
photo4 = ImageTk.PhotoImage(image4)

image5 = Image.open("db22.png")
image5 = image5.resize((180,170), Image.ANTIALIAS)
photo5 = ImageTk.PhotoImage(image5)

image6 = Image.open("db33.png")
image6 = image6.resize((180,170), Image.ANTIALIAS)
photo6 = ImageTk.PhotoImage(image6)

image7 = Image.open("stop.png")
image7 = image7.resize((110,130), Image.ANTIALIAS)
photo7 = ImageTk.PhotoImage(image7)

image8 = Image.open("radio.png")
image8 = image8.resize((220,160), Image.ANTIALIAS)
photo8 = ImageTk.PhotoImage(image8)


image1 = Image.open("back2.png")
test = ImageTk.PhotoImage(image1)
label1 = tk.Label(image=test)
label1.image = test
#label1.place(x=0, y=0)

# button with image binded to the same function 

b4 = tk.Button(root, image=photo4,bg="black",border = 0,command = people_count)
b4.place(x=100, y=650)

b5 = tk.Button(root, image=photo5,bg="black",fg="black",border = 0,command = room_temp)
b5.place(x=440, y=650)

b6 = tk.Button(root, image=photo6,bg="black",fg="black",border = 0,command = vaccin_stock)
b6.place(x=840, y=650)

b7 = tk.Button(root, image=photo7,bg="black",fg="black",border = 0,command = alarm)
b7.place(x=250, y=350)

b8 = tk.Button(root, image=photo8,bg="black",fg="black",border = 0,command = voice_msg)
b8.place(x=600, y=350)



image1 = Image.open("back2.png")
image1 = image1.resize((800,230), Image.ANTIALIAS)
test1 = ImageTk.PhotoImage(image1)
label1 = tk.Label(image=test1,bg="black",border = 0)
label1.image = test1
label1.place(x=370, y=0)

image0 = Image.open("corner2.png")
image0 = image0.resize((450,270), Image.ANTIALIAS)
test0 = ImageTk.PhotoImage(image0)
label0 = tk.Label(image=test0,bg="black",border = 0)
label0.image = test0
label0.place(x=0, y=0)

image8 = Image.open("dcorner2.png")
image8 = image8.resize((450,270), Image.ANTIALIAS)
test8 = ImageTk.PhotoImage(image8)
label8 = tk.Label(image=test8,bg="black",border = 0)
label8.image = test8
label8.place(x=1150, y=570)


image1 = Image.open("dataanalysis.png")
test1 = ImageTk.PhotoImage(image1)
label1 = tk.Label(image=test1,bg="black",border = 0)
label1.image = test1
label1.place(x=410, y=500)

image2 = Image.open("counttxt.png")
test2 = ImageTk.PhotoImage(image2)
label2 = tk.Label(image=test2,bg="black",border = 0)
label2.image = test2
label2.place(x=50, y=580)

image3 = Image.open("temptxt.png")
test3 = ImageTk.PhotoImage(image3)
label3 = tk.Label(image=test3,bg="black",border = 0)
label3.image = test3
label3.place(x=380, y=580)

image4 = Image.open("stacktext.png")
test4 = ImageTk.PhotoImage(image4stacktext
label4 = tk.Label(image=test4,bg="black",border = 0)
label4.image = test4
label4.place(x=750, y=580)

image5 = Image.open("tempslide.png")
test5 = ImageTk.PhotoImage(image5)
label5 = tk.Label(image=test5,bg="black",border = 0)
label5.image = test5
label5.place(x=1200, y=260)

image6 = Image.open("stoptxt.png")
test6 = ImageTk.PhotoImage(image6)
label6 = tk.Label(image=test6,bg="black",border = 0)
label6.image = test6
label6.place(x=150, y=300)

image7 = Image.open("voicemsg.png")
test7 = ImageTk.PhotoImage(image7)
label7 = tk.Label(image=test7,bg="black",border = 0)
label7.image = test7
label7.place(x=520, y=300)

image7 = Image.open("send_msg.png")
test7 = ImageTk.PhotoImage(image7)
label7 = tk.Label(image=test7,bg="black",border = 0)
label7.image = test7
label7.place(x=850, y=300)

b9 = tk.Button(root,text="SEND",bg="green",fg="black",border = 0,command = room1)
b9.place(x=1245, y=605)

b10 = tk.Button(root,text="SEND",bg="green",fg="black",border = 0,command = room2)
b10.place(x=1445, y=605)


canvas1 = tk.Canvas(root, width = 205, height = 25, bg = "black")
canvas1.place(x=900,y=420)
entry1 = tk.Entry (root,width =30) 
canvas1.create_window(100, 13, window=entry1)
button11 = tk.Button(text='Click here to send', command=send_msg,width=12,height=1)
button11.place(x=960,y=470)


w1 = Scale(root,label='TEMP.',
            variable = var1,
            from_=-20 , to=40,
            length=260,
            tickinterval=4,
            orient=VERTICAL,
            bg="black",
            fg="white",
            troughcolor="blue",
            width=20)
w1.place(x=1200,y=340)

w2 = Scale(root,label='TEMP.',
            variable = var2,
            from_=-20 , to=20,
            length=260,
            tickinterval=4,
            orient=VERTICAL,
            bg="black",
            fg="white",
            troughcolor="blue",
            width=20)
w2.place(x=1400,y=340)
#w1 = Scale(root, from_=0, to=42)
#w2 = Scale(root, from_=0, to=200, orient=HORIZONTAL)
#w2.place(x=389,y=389)
#Button(root, text='Show', command=show_values).pack()




# "start the engine"
#root.mainloop()

# final GUI

#home GUI
import tkinter as tk
import plotly
import plotly.graph_objects as go
import pandas as pd
from tkinter import *
from PIL import Image, ImageTk
import os
from plotly.subplots import make_subplots
# %store -r checking_temp
# %store -r checking_hum
# %store -r myhome

HEIGHT=800
WIDTH=700

root= tk.Tk()

os.system("welcome.mp3")

def house():
    global my_img, new_pic, new_pic1,new_pic2,new_pic4,new_pic5,new_pic6,new_pic8,new_pic9,new_pic10,new_pic11,new_pic12,new_pic13
    top= Toplevel()
    top.title('House overall status')
    my_img= ImageTk.PhotoImage(Image.open("houseview.png"))
    my_label= Label(top, image=my_img).pack()
    btn= Button(top, text= "Back to dashboard", command=top.destroy).pack()
    #all on
    if myhome==1: # both ON
        my_img2= Image.open("watering.png")
        resized= my_img2.resize((50,50),Image.ANTIALIAS)
        new_pic=ImageTk.PhotoImage(resized)
        #2nd image
        my_img3= Image.open("watering.png")
        resized1= my_img3.resize((50,50),Image.ANTIALIAS)
        new_pic1=ImageTk.PhotoImage(resized1)
        #heater
        my_heat= Image.open("heateron.png")
        resized2= my_heat.resize((110,160),Image.ANTIALIAS)
        new_pic2=ImageTk.PhotoImage(resized2)
        #labelling
        my_label2= Label(top, image=new_pic)
        my_label2.place(relx=0.2, rely=0.2, relwidth=0.06, relheight=0.06)
        my_label3= Label(top, image=new_pic1)
        my_label3.place(relx=0.65, rely=0.2, relwidth=0.06, relheight=0.06)
        my_label4= Label(top, image=new_pic2)
        my_label4.place(relx=0.3, rely=0.45, relwidth=0.03, relheight=0.09)
        os.system("bothON.mp3")
    elif myhome==2: ## heater off, water on
        my_img8= Image.open("watering.png")
        resized8= my_img8.resize((50,50),Image.ANTIALIAS)
        new_pic8=ImageTk.PhotoImage(resized8)
        #2nd image
        my_img9= Image.open("watering.png")
        resized9= my_img9.resize((50,50),Image.ANTIALIAS)
        new_pic9=ImageTk.PhotoImage(resized9)
        #heater
        my_heat10= Image.open("heateroff.png")
        resized10= my_heat10.resize((110,160),Image.ANTIALIAS)
        new_pic10=ImageTk.PhotoImage(resized10)
        #labelling
        my_label8= Label(top, image=new_pic8)
        my_label8.place(relx=0.2, rely=0.2, relwidth=0.06, relheight=0.06)
        my_label9= Label(top, image=new_pic9)
        my_label9.place(relx=0.65, rely=0.2, relwidth=0.06, relheight=0.06)
        my_label10= Label(top, image=new_pic10)
        my_label10.place(relx=0.3, rely=0.45, relwidth=0.03, relheight=0.09)
        os.system("HeaterOffwaterON.mp3")
    elif myhome==3: ## heater on, water off
        my_img11= Image.open("pngplant.png")
        resized11= my_img11.resize((100,100),Image.ANTIALIAS)
        new_pic11=ImageTk.PhotoImage(resized11)
        #2nd image
        my_img12= Image.open("pngplant.png")
        resized12= my_img12.resize((100,100),Image.ANTIALIAS)
        new_pic12=ImageTk.PhotoImage(resized12)
        #heater
        my_heat13= Image.open("heateron.png")
        resized13= my_heat13.resize((110,160),Image.ANTIALIAS)
        new_pic13=ImageTk.PhotoImage(resized13)
        #labelling
        my_label11= Label(top, image=new_pic11)
        my_label11.place(relx=0.2, rely=0.2, relwidth=0.06, relheight=0.06)
        my_label12= Label(top, image=new_pic12)
        my_label12.place(relx=0.65, rely=0.2, relwidth=0.06, relheight=0.06)
        my_label13= Label(top, image=new_pic13)
        my_label13.place(relx=0.3, rely=0.45, relwidth=0.03, relheight=0.09)
        os.system("HeaterONwaterOff.mp3")      
    else: #all off
        my_img4= Image.open("pngplant.png")
        resized4= my_img4.resize((100,100),Image.ANTIALIAS)
        new_pic4=ImageTk.PhotoImage(resized4)
        #2nd image
        my_img5= Image.open("pngplant.png")
        resized5= my_img5.resize((100,100),Image.ANTIALIAS)
        new_pic5=ImageTk.PhotoImage(resized5)
        #heater
        my_heat1= Image.open("heateroff.png")
        resizedh= my_heat1.resize((110,160),Image.ANTIALIAS)
        new_pic6=ImageTk.PhotoImage(resizedh)
        #labelling
        my_label5= Label(top, image=new_pic4)
        my_label5.place(relx=0.2, rely=0.2, relwidth=0.06, relheight=0.06)
        my_label6= Label(top, image=new_pic5)
        my_label6.place(relx=0.65, rely=0.2, relwidth=0.06, relheight=0.06)
        my_label7= Label(top, image=new_pic6)
        my_label7.place(relx=0.3, rely=0.45, relwidth=0.03, relheight=0.09)
        os.system("bothOFF.mp3")   
        
 
   
def LSTM_temp():  
    fig = make_subplots(specs=[[{"secondary_y": True}]])
    
    excel_file_t = 'forecastLSTM.xlsx'
    df3 = pd.read_excel(excel_file_t)
    excel_file_h = 'forecastLSTM_h.xlsx'
    df4 = pd.read_excel(excel_file_h)
    
    print(df3)
    print(df4)
    
    fig.add_trace(
    go.Scatter(x=df3['Date'],y=df3['Temperature'], name = "LSTM temperature"),
    secondary_y=False,
    )
    fig.add_trace(
    go.Scatter(x=df4['Date'],y=df4['Humidity'], name = "LSTM humidity"),
    secondary_y=False,
    )
    fig.update_layout(
    title_text="Forecast of Temperature and Humidity "
    )
    fig.update_xaxes(title_text="<b>Date</b>")
    fig.update_yaxes(title_text="<b>Values</b>", secondary_y=False)
    #fig.show()
    plotly.offline.plot(fig, filename="LSTM_Output.html")

    
    
def deviation():  
    fig = make_subplots(specs=[[{"secondary_y": True}]])
    
    excel_file = 'forecastLSTM.xlsx'
    df1 = pd.read_excel(excel_file)
    excel_file2 = 'dev.xlsx'
    df2 = pd.read_excel(excel_file2)
    
    print(df1)
    print(df2)
    
    fig.add_trace(
    go.Scatter(x=df1['Date'],y=df1['Temperature'], name = "LSTM temperature"),
    secondary_y=False,
    )
    fig.add_trace(
    go.Scatter(x=df2['Date'],y=df2['Temperature'], name = "temperature of Pi"),
    secondary_y=False,
    )
    fig.update_layout(
    title_text="Deviation "
    )
    fig.update_xaxes(title_text="<b>Date</b>")
    fig.update_yaxes(title_text="<b>Temperature</b>", secondary_y=False)
    #fig.show()
    plotly.offline.plot(fig, filename="deviation_temperature.html")


    
def raspi():  
    fig = make_subplots(specs=[[{"secondary_y": True}]])

    excel_file1 = 'rasp_input.csv'
    df1 = pd.read_csv(excel_file1)
    print(df1)

    fig.add_trace(
    go.Scatter(x=df1['Date'],y=df1['Temperature'], name = "temperature"),
    secondary_y=False,
    )

    fig.add_trace(
    go.Scatter(x=df1['Date'],y=df1['Humidity'], name="Humidity")
    )

    fig.update_layout(
    title_text="RaspberryPi sensor values "
    )
    fig.update_xaxes(title_text="<b>Date</b>")
    fig.update_yaxes(title_text="<b>values</b>", secondary_y=False)
    #fig.show()
    plotly.offline.plot(fig, filename="Raspberrypi_temperature.html")




canvas1 = tk.Canvas(root, width = WIDTH, height = HEIGHT)
canvas1.place(x=1000,y=1000)
canvas1.pack()

image5 = Image.open("transparent-smart-house-icon-dashboard-icon-home-icon-5d776b2072a478.4403257515681072964696.png")
image5 = image5.resize((150,150), Image.ANTIALIAS)
photo5 = ImageTk.PhotoImage(image5)

image1 = Image.open("neuralnetwork2.png")
image1 = image1.resize((140,140), Image.ANTIALIAS)
photo1 = ImageTk.PhotoImage(image1)

image2 = Image.open("raspi.png")
image2 = image2.resize((140,140), Image.ANTIALIAS)
photo2 = ImageTk.PhotoImage(image2)

image3 = Image.open("deviation.png")
image3 = image3.resize((140,150), Image.ANTIALIAS)
photo3 = ImageTk.PhotoImage(image3)

frame= tk.Frame(root, bg="black")
frame.place(relx=0.1, rely=0.1, relwidth=0.8,relheight=0.8)

#image3 = Image.open("pots.png")
#test = ImageTk.PhotoImage(image3)
#label4 = tk.Label(image=test)
#label4.image = test
#label4.place(x=0, y=0)


    
    
button = tk.Button(frame, image=photo5,bg="black",fg="black",border = 5, command= house)
button.place(relx=0.1, rely=0.6, relwidth=0.8, relheight=0.25)


button1 = tk.Button(frame, image=photo1, bg="black",fg="black",border = 5, command= LSTM_temp)
button1.place(relx=0.1, rely=0.3, relwidth=0.25, relheight=0.25)

button2 = tk.Button(frame, image=photo2, bg="black",fg="black",border =5, command=raspi)
button2.place(relx=0.4, rely=0.3, relwidth=0.25, relheight=0.25)

button = tk.Button(frame, image=photo3,bg="black",fg="black",border = 5, command=deviation)
button.place(relx=0.7, rely=0.3, relwidth=0.25, relheight=0.25)



root.mainloop()
